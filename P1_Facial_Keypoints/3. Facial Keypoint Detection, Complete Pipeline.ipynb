# %% [markdown]
# ## Face and Facial Keypoint detection
#
# After you've trained a neural network to detect facial keypoints, you can then apply this network to *any* image that includes faces. The neural network expects a Tensor of a certain size as input and, so, to detect any face, you'll first have to do some pre-processing.
#
# 1. Detect all the faces in an image using a face detector (we'll be using a Haar Cascade detector in this notebook).
# 2. Pre-process those face images so that they are grayscale, and transformed to a Tensor of the input size that your net expects. This step will be similar to the `data_transform` you created and applied in Notebook 2, whose job was tp rescale, normalize, and turn any iimage into a Tensor to be accepted as input to your CNN.
# 3. Use your trained model to detect facial keypoints on the image.
#
# ---

# %% [markdown]
# In the next python cell we load in required libraries for this section of the project.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %% [markdown]
# #### Select an image
#
# Select an image to perform facial keypoint detection on; you can select any image of faces in the `images/` directory.

# %%
import cv2
# load in color image for face detection
#image = cv2.imread('images/obamas.jpg')
image = cv2.imread('images/infinitywar.jpg')

# switch red and blue color channels 
# --> by default OpenCV assumes BLUE comes first, not RED as in many images
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# plot the image
fig = plt.figure(figsize=(9,9))
plt.imshow(image)

# %% [markdown]
# ## Detect all faces in an image
#
# Next, you'll use one of OpenCV's pre-trained Haar Cascade classifiers, all of which can be found in the `detector_architectures/` directory, to find any faces in your selected image.
#
# In the code below, we loop over each face in the original image and draw a red square on each face (in a copy of the original image, so as not to modify the original). You can even [add eye detections](https://docs.opencv.org/3.4.1/d7/d8b/tutorial_py_face_detection.html) as an *optional* exercise in using Haar detectors.
#
# An example of face detection on a variety of images is shown below.
#
# <img src='images/haar_cascade_ex.png' width=80% height=80%/>

# %%
# load in a haar cascade classifier for detecting frontal faces
face_cascade = cv2.CascadeClassifier('detector_architectures/haarcascade_frontalface_default.xml')

# run the detector
# the output here is an array of detections; the corners of each detection box
# if necessary, modify these parameters until you successfully identify every face in a given image
faces = face_cascade.detectMultiScale(image, 1.3, 6)

# make a copy of the original image to plot detections on
image_with_detections = image.copy()

# loop over the detected faces, mark the image where each face is found
for (x,y,w,h) in faces:
    # draw a rectangle around each detected face
    # you may also need to change the width of the rectangle drawn depending on image resolution
    cv2.rectangle(image_with_detections,(x,y),(x+w,y+h),(255,0,0),10) 

fig = plt.figure(figsize=(15,15))

plt.imshow(image_with_detections)

# %% [markdown]
# ## Loading in a trained model
#
# Once you have an image to work with (and, again, you can select any image of faces in the `images/` directory), the next step is to pre-process that image and feed it into your CNN facial keypoint detector.
#
# First, load your best model by its filename.

# %%
import torch
from models import Net

net = Net(in_channels=3)

## TODO: load the best saved model parameters (by your path name)
## You'll need to un-comment the line below and add the correct name for *your* saved model
net.load_state_dict(torch.load('saved_models/keypoints_model_rgb_1.pt'))

## print out your net and prepare it for testing (uncomment the line below)
net.eval()
# Out:
# Net(
#   (conv1a): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv1a_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv1b): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv1b_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop1): Dropout2d(p=0.3)
#   (conv2a): Conv2d(64, 128, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1))
#   (conv2a_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2b): Conv2d(128, 128, kernel_size=(2, 2), stride=(1, 1))
#   (conv2b_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2c): Conv2d(128, 128, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1))
#   (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2c_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop2): Dropout2d(p=0.3)
#   (conv3a): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3a_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3b): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3b_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3c): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (maxpool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3c_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop3): Dropout2d(p=0.3)
#   (conv4a): Conv2d(256, 512, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1))
#   (conv4a_bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4b): Conv2d(512, 512, kernel_size=(2, 2), stride=(1, 1))
#   (conv4b_bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4c): Conv2d(512, 512, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1))
#   (maxpool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv4c_bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop4): Dropout2d(p=0.3)
#   (conv5): Conv2d(512, 136, kernel_size=(2, 2), stride=(1, 1))
#   (maxpool5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv5_bn): BatchNorm2d(136, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (gapool): AdaptiveAvgPool2d(output_size=1)
#   (linear): Linear(in_features=136, out_features=136, bias=True)
# )

# %% [markdown]
# ## Keypoint detection
#
# Now, we'll loop over each detected face in an image (again!) only this time, you'll transform those faces in Tensors that your CNN can accept as input images.
#
# ### TODO: Transform each detected face into an input Tensor
#
# You'll need to perform the following steps for each detected face:
# 1. Convert the face from RGB to grayscale
# 2. Normalize the grayscale image so that its color range falls in [0,1] instead of [0,255]
# 3. Rescale the detected face to be the expected square size for your CNN (224x224, suggested)
# 4. Reshape the numpy image into a torch image.
#
# You may find it useful to consult to transformation code in `data_load.py` to help you perform these processing steps.
#
#
# ### TODO: Detect and display the predicted keypoints
#
# After each face has been appropriately converted into an input Tensor for your network to see as input, you'll wrap that Tensor in a Variable() and can apply your `net` to each face. The ouput should be the predicted the facial keypoints. These keypoints will need to be "un-normalized" for display, and you may find it helpful to write a helper function like `show_keypoints`. You should end up with an image like the following with facial keypoints that closely match the facial features on each individual face:
#
# <img src='images/michelle_detected.png' width=30% height=30%/>

# %%
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from torch import FloatTensor

# the transforms we defined in Notebook 1 are in the helper file `data_load.py`
from data_load import Rescale, RandomCrop, Normalize, ToTensor

def show_keypoints(image, key_pts, axis):
    """Show image with predicted keypoints"""
    # image is grayscale
    axis.imshow(image, cmap='gray')
    axis.scatter(key_pts[:, 0], key_pts[:, 1], s=20, marker='.', c='m')
    for i in range(len(key_pts[:, 0])):
        axis.annotate(str(i), (key_pts[i, 0],key_pts[i, 1]))

def net_output(net, image):
    ## TODO: Make facial keypoint predictions using your loaded, trained network 
    ## perform a forward pass to get the predicted facial keypoints

    # convert image to FloatTensor
    # wrap image in a torch Variable
    image = Variable(FloatTensor(image))

    # forward pass to get net output
    output_pts = net.forward(image).data.numpy()[0]

    # reshape to 68 x 2 pts
    output_pts = output_pts.reshape(68, 2)
    #print(output_pts)
    return output_pts

def roi_transform(roi, output_size=224):
    
    ## TODO: Convert the face region from RGB to grayscale
    #roi = cv2.cvtColor(roi, cv2.COLOR_RGB2GRAY)
    
    ## TODO: Normalize the grayscale image so that its color range falls in [0,1] instead of [0,255]
    roi = roi / 255.0
    
    ## TODO: Rescale the detected face to be the expected square size for your CNN (224x224, suggested)
    roi = cv2.resize(roi, (output_size, output_size))
      
    ## TODO: Reshape the numpy image shape (H x W x C) into a torch image shape (C x H x W)
    # if image has no grayscale color channel, add one
    if(len(roi.shape) == 2):
        roi = roi.reshape(roi.shape[0], roi.shape[1], 1)
    roi = roi.transpose((2, 0, 1))
    roi = roi.reshape(1, *roi.shape)
    #print(roi.shape)
    return roi

# loop over the detected faces from your haar cascade
output_size = 224
image_copy = np.copy(image)
roi = []
roi_output = []
for (x,y,w,h) in faces:
    # Select the region of interest that is the face in the image
    scale = 1.3
    y = int(y - ((scale-1)/2)*h)
    x = int(x - ((scale-1)/2)*w)
    h = int(scale * h)
    w = int(scale * w)
    r = image_copy[y:y+h, x:x+w]
    roi.append(r)
    #roi.append(cv2.resize(r, (output_size, output_size)))
    key_pts = net_output(net, roi_transform(r, output_size))
    key_pts[:, 0] = (key_pts[:, 0] + 1) * w/2 # x
    key_pts[:, 1] = (key_pts[:, 1] + 1) * h/2 # y
    #key_pts = (key_pts + 1) * output_size/2
    roi_output.append(key_pts)

#for r, o in roi, roi_output:
#    show_keypoints(r, o)
num = len(roi)
fig = plt.figure(figsize=(15,15))
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)
for i in range(num):
    ax = fig.add_subplot((len(faces)+2)//3, 3, i + 1, xticks=[], yticks=[])
    show_keypoints(roi[i], roi_output[i], ax)
